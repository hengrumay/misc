# %% [markdown]
# #### <a href="00_Synthetic_Data_Generator.html">00_Synthetic_Data_Generator</a>
# #### <a href="01_Stitch_Transcripts.html">01_Stitch_Transcripts</a>
# #### <a href="02_AI_Scoring.html">02_AI_Scoring</a>
# #### <a href="03_LLM_Judge_Evals.html">03_LLM_Judge_Evals</a>
# #### <a href="04_Dashboard.html">04_Dashboard</a>
# #### <a href="05_Genie_AI_Skill.html">05_Genie_AI_Skill</a>
# #### <a href="index.html">index</a>
